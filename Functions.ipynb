# %% [markdown]
# # Functions

# %% [markdown]
# 1. what is funtion in python
#    - this is the answer of is function in python
#
# 2. this is seecond question
#    - this is answer for second question

# %%
# Question
'''
this is also a another way

'''
"""
this also a good way

"""
# Out:
# '\nthis also a good way\n\n'
